# %% [markdown]
# # Lista 01: Grandezas e Lei de Ohm (Cálculos de Cabeça)
#
# **Parte 1: Conversão Instantânea de Unidades**
#
# Transforme os valores para a unidade fundamental (Ohms, Amperes ou Volts).
# * 1. $1,2\text{ k}\Omega$ para $\Omega$
# * 2. $470\text{ m}A$ para $A$
# * 3. $0,05\text{ M}\Omega$ para $\Omega$
# * 4. $15\text{ }\mu A$ para $A$
# * 5. $220\text{ k}\Omega$ para $\Omega$
#
# ---
#
# **Parte 2: Resistores para LEDs**
#
# Considere um LED padrão com queda de tensão ($V_f$) de $2V$ e corrente desejada de $20\text{ mA}$ ($0,02A$). Use a fórmula:
#
# $$R = \frac{V_{fonte} - V_{led}}{I}$$
#
# * 6. Fonte de $5V$: Qual o valor de $R$?
# * 7. Fonte de $9V$: Qual o valor de $R$?
# * 8. Fonte de $12V$: Qual o valor de $R$?
# * 9. Fonte de $3,3V$: Qual o valor de $R$?
# * 10. Fonte de $24V$: Qual o valor de $R$?
#
# ---
#
# **Parte 3: Corrente em Circuitos Série**
#
# Determine a corrente total ($I$) que atravessa o circuito. Lembre-se: $R_{total} = R_1 + R_2$ e $I = \frac{V}{R_{total}}$.
#
# * 11. $V = 10V$ | $R_1 = 100\Omega$, $R_2 = 400\Omega$
# * 12. $V = 5V$ | $R_1 = 1\text{ k}\Omega$, $R_2 = 1,5\text{ k}\Omega$
# * 13. $V = 12V$ | $R_1 = 10\Omega$, $R_2 = 2\Omega$
# * 14. $V = 9V$ | $R_1 = 300\Omega$, $R_2 = 600\Omega$
# * 15. $V = 20V$ | $R_1 = 2\text{ k}\Omega$, $R_2 = 8\text{ k}\Omega$
